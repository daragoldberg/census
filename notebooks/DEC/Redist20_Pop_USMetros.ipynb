# %%
import pandas as pd
import numpy as np
import os
import glob

# %%
from r_codes import geo_col,col1,col2,col3
from geo import stco_fips, metro_codes

# %%
col_head = {'o':geo_col,'1':col1,'2':col2,'3':col3}
col_join = ['LOGRECNO','STUSAB','FILEID','CHARITER']
col_data = ['STATE','COUNTY','GEOCODE','SUMLEV','POP100','HU100','P0010001','H0010001','H0010002','H0010003','NAME']

# %%
# set directory
folders = glob.glob('../data/red_metro_20/*')

# %% [markdown]
# ### data pulling functions for regional data

# %%
def make_state(state):
    files = glob.glob(f'../data/red_metro_20/{state}2020.pl/*.pl')
    #for first file in folder
    df = pd.read_table(f'{files[0]}',sep='|',header=None,low_memory=False,encoding = 'unicode_escape')
    df.columns = col_head[files[0][-8]]

    #for all other files
    for file in files[1:]:
        dff = pd.read_table(f'{file}',sep='|',header=None,low_memory=False,encoding = 'unicode_escape')
        dff.columns = col_head[file[-8]]
        df = pd.merge(df,dff,left_on=col_join,right_on=col_join,how="inner")
    
    #reduce table size
    df = df[col_data] #just the data columns we need
    df = df[df.SUMLEV==50].copy() #just county data
    return df

# %%
def make_table(folders):
    df = pd.DataFrame()
    for folder in folders:
        state = folder[-9:-7]
        dff = make_state(state)
        df = pd.concat([df,dff])
    return df

# %% [markdown]
# ### make various tables

# %%
#master table for counties
master = make_table(folders)

# %%
master.head()
# Out:
#    STATE  COUNTY GEOCODE  SUMLEV  POP100   HU100  P0010001  H0010001  \
# 1     25     1.0   25001      50  228996  164885    228996    164885
# 2     25     3.0   25003      50  129026   69759    129026     69759
# 3     25     5.0   25005      50  579200  243464    579200    243464
# 4     25     7.0   25007      50   20600   17530     20600     17530
# 5     25     9.0   25009      50  809829  327185    809829    327185
#
#    H0010002  H0010003               NAME
# 1    103368     61517  Barnstable County
# 2     57015     12744   Berkshire County
# 3    229293     14171     Bristol County
# 4      8932      8598       Dukes County
# 5    309030     18155       Essex County

# %%
# pull in us metro list
geo = pd.read_csv('../data/geo/usmetros_cnty.csv')
geo['stco_id'] = geo['stco'].apply(lambda x:'{0:0>5}'.format(x))

# %%
cty = pd.merge(geo,master,left_on='stco_id',right_on='GEOCODE',how='left')

# %%
cty.head()
# Out:
#    csa_id                                           csa_name  st_id  co_id  \
# 0     122  Atlanta--Athens-Clarke County--Sandy Springs, ...      1     17
# 1     429                                   Phoenix-Mesa, AZ      4      7
# 2     429                                   Phoenix-Mesa, AZ      4     21
# 3     429                                   Phoenix-Mesa, AZ      4     13
# 4     472                           Sacramento-Roseville, CA      6     57
#
#    stco   co_name     st_name stco_id  STATE  COUNTY GEOCODE  SUMLEV   POP100  \
# 0  1017  Chambers     Alabama   01017      1    17.0   01017      50    34772
# 1  4007      Gila     Arizona   04007      4     7.0   04007      50    53272
# 2  4021     Pinal     Arizona   04021      4    21.0   04021      50   425264
# 3  4013  Maricopa     Arizona   04013      4    13.0   04013      50  4420568
# 4  6057    Nevada  California   06057      6    57.0   06057      50   102241
#
#      HU100  P0010001  H0010001  H0010002  H0010003             NAME
# 0    16373     34772     16373     14238      2135  Chambers County
# 1    32373     53272     32373     22312     10061      Gila County
# 2   172878    425264    172878    146663     26215     Pinal County
# 3  1812827   4420568   1812827   1643579    169248  Maricopa County
# 4    53627    102241     53627     42774     10853    Nevada County

# %%
metro = cty[['csa_id','csa_name','P0010001','H0010001','H0010002','H0010003']]
metro = metro.groupby(['csa_id','csa_name']).sum().reset_index()

# %%
metro
# Out:
#     csa_id                                           csa_name  P0010001  \
# 0      122  Atlanta--Athens-Clarke County--Sandy Springs, ...   6930423
# 1      148           Boston-Worcester-Providence, MA-RI-NH-CT   8466186
# 2      172                           Charlotte-Concord, NC-SC   2822352
# 3      176                       Chicago-Naperville, IL-IN-WI   9986960
# 4      184                         Cleveland-Akron-Canton, OH   3633962
# 5      206                           Dallas-Fort Worth, TX-OK   8121108
# 6      216                                  Denver-Aurora, CO   3623560
# 7      220                       Detroit-Warren-Ann Arbor, MI   5424742
# 8      288                          Houston-The Woodlands, TX   7312270
# 9      348                         Los Angeles-Long Beach, CA  18644680
# 10     370           Miami-Port St. Lucie-Fort Lauderdale, FL   6868652
# 11     378                        Minneapolis-St. Paul, MN-WI   4078788
# 12     408                       New York-Newark, NY-NJ-CT-PA  23544043
# 13     422                       Orlando-Lakeland-Deltona, FL   4222422
# 14     428           Philadelphia-Reading-Camden, PA-NJ-DE-MD   7379700
# 15     429                                   Phoenix-Mesa, AZ   4899104
# 16     430            Pittsburgh-New Castle-Weirton, PA-OH-WV   2657149
# 17     440                    Portland-Vancouver-Salem, OR-WA   3280736
# 18     472                           Sacramento-Roseville, CA   2680831
# 19     476            St. Louis-St. Charles-Farmington, MO-IL   2924904
# 20     482                      Salt Lake City-Provo-Orem, UT   2701129
# 21     484             San Antonio-New Braunfels-Pearsall, TX   2576528
# 22     488                 San Jose-San Francisco-Oakland, CA   9714023
# 23     500                                 Seattle-Tacoma, WA   4953421
# 24     548     Washington-Baltimore-Arlington, DC-MD-VA-WV-PA   9973383
#
#     H0010001  H0010002  H0010003
# 0    2753914   2570167    183747
# 1    3604952   3319384    285568
# 2    1179478   1098647     80831
# 3    4107480   3819959    287521
# 4    1662778   1525555    137223
# 5    3163911   2947316    216595
# 6    1503302   1414008     89294
# 7    2350647   2176590    174057
# 8    2821424   2577581    243843
# 9    6595294   6205567    389727
# 10   3007747   2637311    370436
# 11   1664221   1583984     80237
# 12   9378745   8690671    688074
# 13   1817344   1613489    203855
# 14   3119160   2843987    275173
# 15   2018078   1812554    205524
# 16   1257734   1143552    114182
# 17   1333284   1263512     69772
# 18   1051146    971304     79842
# 19   1304856   1190236    114620
# 20    921854    865530     56324
# 21   1022018    930799     91219
# 22   3606733   3410592    196141
# 23   2051279   1929118    122161
# 24   4006033   3749833    256200

# %%
metro.to_csv('output/metros_20.csv')
