# %%
import pandas as pd
import numpy as np
import os

# %%
states = ['st09_ct','st34_nj','st36_ny']

# %% [markdown]
# ## Census Block 2010 to Census Block 2020

# %%
df = pd.DataFrame()
for state in states:
    dff = pd.read_csv(f'../data/tab2010_tab2020_{state}.txt',delimiter='|')
    df = pd.concat([df,dff])

# %%
df.dtypes
# Out:
# STATE_2010             int64
# COUNTY_2010            int64
# TRACT_2010             int64
# BLK_2010               int64
# BLKSF_2010           float64
# AREALAND_2010          int64
# AREAWATER_2010         int64
# BLOCK_PART_FLAG_O     object
# STATE_2020             int64
# COUNTY_2020            int64
# TRACT_2020             int64
# BLK_2020               int64
# BLKSF_2020           float64
# AREALAND_2020          int64
# AREAWATER_2020         int64
# BLOCK_PART_FLAG_R     object
# AREALAND_INT           int64
# AREAWATER_INT          int64
# dtype: object

# %%
years = ['2010','2020']
for y in years:
    df[f'id_{y}'] = df[f'STATE_{y}'].astype(str).apply(lambda x: '{0:0>2}'.format(x)) +\
                df[f'COUNTY_{y}'].astype(str).apply(lambda x: '{0:0>3}'.format(x)) +\
                df[f'TRACT_{y}'].astype(str).apply(lambda x: '{0:0>6}'.format(x)) +\
                df[f'BLK_{y}'].astype(str).apply(lambda x: '{0:0>4}'.format(x))
    df[f'stco_{y}'] = df[f'id_{y}'].str[:5]

# %%
df.head()
# Out:
#    STATE_2010  COUNTY_2010  TRACT_2010  BLK_2010  BLKSF_2010  AREALAND_2010  \
# 0           9            1       10101      1000         NaN          24210
# 1           9            1       10101      1000         NaN          24210
# 2           9            1       10101      1001         NaN        1205217
# 3           9            1       10101      1001         NaN        1205217
# 4           9            1       10101      1002         NaN            486
#
#    AREAWATER_2010 BLOCK_PART_FLAG_O  STATE_2020  COUNTY_2020  ...  BLKSF_2020  \
# 0               0                 p           9            1  ...         NaN
# 1               0                 p           9            1  ...         NaN
# 2               0                 p           9            1  ...         NaN
# 3               0                 p           9            1  ...         NaN
# 4               0               NaN           9            1  ...         NaN
#
#    AREALAND_2020  AREAWATER_2020  BLOCK_PART_FLAG_R  AREALAND_INT  \
# 0        1219040               0                  p         22492
# 1          12702               0                  p          1718
# 2        1219040               0                  p       1194233
# 3          12702               0                  p         10984
# 4        1219040               0                  p           486
#
#   AREAWATER_INT          id_2010  stco_2010          id_2020 stco_2020
# 0             0  090010101011000      09001  090010101014000     09001
# 1             0  090010101011000      09001  090010101014001     09001
# 2             0  090010101011001      09001  090010101014000     09001
# 3             0  090010101011001      09001  090010101014001     09001
# 4             0  090010101011002      09001  090010101014000     09001
#
# [5 rows x 22 columns]

# %%
reg = pd.read_csv(f'../data/31CR_CoxSub.csv')

# %%
reg['stco']=reg['stco'].astype(str).apply(lambda x: '{0:0>5}'.format(x))

# %%
nycmetro = df.merge(reg,left_on="stco_2020", right_on="stco").drop(columns=['st','co','stco'])

# %%
nycmetro.head()
# Out:
#    STATE_2010  COUNTY_2010  TRACT_2010  BLK_2010  BLKSF_2010  AREALAND_2010  \
# 0           9            1       10101      1000         NaN          24210
# 1           9            1       10101      1000         NaN          24210
# 2           9            1       10101      1001         NaN        1205217
# 3           9            1       10101      1001         NaN        1205217
# 4           9            1       10101      1002         NaN            486
#
#    AREAWATER_2010 BLOCK_PART_FLAG_O  STATE_2020  COUNTY_2020  ...  \
# 0               0                 p           9            1  ...
# 1               0                 p           9            1  ...
# 2               0                 p           9            1  ...
# 3               0                 p           9            1  ...
# 4               0               NaN           9            1  ...
#
#            id_2010  stco_2010          id_2020  stco_2020  stco_int   reg  \
# 0  090010101011000      09001  090010101014000      09001      9001  31CR
# 1  090010101011000      09001  090010101014001      09001      9001  31CR
# 2  090010101011001      09001  090010101014000      09001      9001  31CR
# 3  090010101011001      09001  090010101014001      09001      9001  31CR
# 4  090010101011002      09001  090010101014000      09001      9001  31CR
#
#    subreg1  subreg2                       stco_lbl     co_lbl
# 0       CT       CT  Fairfield County, Connecticut  Fairfield
# 1       CT       CT  Fairfield County, Connecticut  Fairfield
# 2       CT       CT  Fairfield County, Connecticut  Fairfield
# 3       CT       CT  Fairfield County, Connecticut  Fairfield
# 4       CT       CT  Fairfield County, Connecticut  Fairfield
#
# [5 rows x 28 columns]

# %% [markdown]
# ## Old changes file (for 2010 census?)

# %%
#old geo changes (all are 2012 and earlier?)

states2 = ['connecticut','new-jersey','new-york']
path = "https://www2.census.gov/geo/docs/reference/bndrychange/"

new=pd.DataFrame()
for st in states2:
    sts = pd.read_csv(f'{path}{st}.txt',delimiter='|')
    new = pd.concat([new,sts])

# %%
new.head()
# Out:
#    State Area Name (with parent county and code)   Code  \
# 0      9         Colchester CDP (New London-011)  15840
# 1      9          Franklin town (New London-011)  29910
# 2      9           Lebanon town (New London-011)  42390
# 3      9                       Litchfield County      5
# 4      9                       Litchfield County      5
#
#            Type of Change Effective Date  Effective_Year  Effective_Month  \
# 0              New Entity     01/01/2007            2007                1
# 1     Boundary Correction     01/01/2003            2003                1
# 2     Boundary Correction     01/01/2003            2003                1
# 3  County Boundary Change     09/03/2009            2009                9
# 4  County Boundary Change     09/03/2009            2009                9
#
#    Effective_Day                              Description of Change  \
# 0              1  Located in New London County (011), Colchester...
# 1              1            Lost territory to Lebanon town (42390).
# 2              1       Gained territory from Franklin town (29910).
# 3              3  Litchfield County (005), Watertown town (80490...
# 4              3  Litchfield County (005), Watertown town (80490...
#
#                  Source of Change Date Submitted
# 0                   Census Bureau     07/07/2007
# 1  Boundary and Annexation Survey     05/02/2003
# 2  Boundary and Annexation Survey     05/02/2003
# 3  Boundary and Annexation Survey     01/19/2010
# 4  Boundary and Annexation Survey     02/14/2011

# %%
new.to_excel('geo_changes.xlsx')

# %% [markdown]
# ## 2020 Places and Subdivisions

# %%
states3 = ['09','34','36']
path_sub = 'https://www2.census.gov/geo/docs/maps-data/data/gazetteer/2020_Gazetteer/2020_gaz_cousubs_'
path_place = 'https://www2.census.gov/geo/docs/maps-data/data/gazetteer/2020_Gazetteer/2020_gaz_place_36.txt'

new=pd.DataFrame()
for st in states3:
    sts = pd.read_csv(f'{path_sub}{st}.txt',delimiter='\t')
    new = pd.concat([new,sts])

# %%
new['GEOID_str'] = new['GEOID'].astype(str).apply(lambda x:'{0:0>10}'.format(x))
new['stco'] = new['GEOID_str'].str[:5]

# %%
stco = list(reg['stco'].unique())

# %%
new_reg = new[new.stco.isin(stco)]

# %%
pl = pd.read_csv(f'{path_place}',delimiter='\t')

# %%
pl.head()
# Out:
#   USPS    GEOID  ANSICODE              NAME  LSAD FUNCSTAT     ALAND  AWATER  \
# 0   NY  3600155   2389116        Accord CDP    57        S   8806877  112414
# 1   NY  3600199   2391499     Adams village    47        A   3742271       0
# 2   NY  3600232   2389117  Adams Center CDP    57        S  12587226  350864
# 3   NY  3600276   2391500   Addison village    47        A   4902284       0
# 4   NY  3600342   2391501     Afton village    47        A   3953884  189228
#
#    ALAND_SQMI  AWATER_SQMI   INTPTLAT  \
# 0       3.400        0.043  41.801491
# 1       1.445        0.000  43.810218
# 2       4.860        0.135  43.869989
# 3       1.893        0.000  42.106321
# 4       1.527        0.073  42.229199
#
#    INTPTLONG
# 0                                         -74.230258
# 1                                         -76.022978
# 2                                         -75.988663
# 3                                         -77.231990
# 4                                         -75.524750
